# %%
import pandas as pd
import numpy as np

# %%
dict1={"name":["harray",'rohan','skillf','shubh'],
       "marks":[92,34,24,17],
       "city":['rampur','Kolkata','bareilly','attatica']
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks      city
# 0  harray     92    rampur
# 1   rohan     34   Kolkata
# 2  skillf     24  bareilly
# 3   shubh     17  attatica

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends.csv_index_false',index=False)

# %%
df.head(2)
# Out:
#      name  marks     city
# 0  harray     92   rampur
# 1   rohan     34  Kolkata

# %%
df.tail(2)
# Out:
#      name  marks      city
# 2  skillf     24  bareilly
# 3   shubh     17  attatica

# %%
vaibhav=pd.read_csv('test_new.csv')

# %%
vaibhav
# Out:
#    Unnamed: 0  a   b   c
# 0           0  1   6  11
# 1           1  2   7  12
# 2           2  3   8  13
# 3           3  4   9  14
# 4           4  5  10  15

# %%
vaibhav.index=['a','b','c','d','e']

# %%
vaibhav
# Out:
#    Unnamed: 0  a   b   c
# a           0  1   6  11
# b           1  2   7  12
# c           2  3   8  13
# d           3  4   9  14
# e           4  5  10  15

# %%
ser=pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.926890
# 1     0.910912
# 2     0.703258
# 3     0.453508
# 4     0.367136
# 5     0.934431
# 6     0.197905
# 7     0.469615
# 8     0.522332
# 9     0.136333
# 10    0.281643
# 11    0.244943
# 12    0.956258
# 13    0.591663
# 14    0.308026
# 15    0.715924
# 16    0.576808
# 17    0.278306
# 18    0.240852
# 19    0.917014
# 20    0.044285
# 21    0.108078
# 22    0.229960
# 23    0.701043
# 24    0.475521
# 25    0.983162
# 26    0.736028
# 27    0.910424
# 28    0.916700
# 29    0.073534
# 30    0.400946
# 31    0.355381
# 32    0.044533
# 33    0.808678
# dtype: float64

# %%
newdf = pd.DataFrame(np.random.rand(344,5),index=np.arange(344))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.424425  0.646496  0.434950  0.414120  0.522965
# 1    0.932872  0.042763  0.513731  0.237541  0.836702
# 2    0.785173  0.663153  0.049380  0.763408  0.525720
# 3    0.735370  0.685781  0.842727  0.632564  0.543993
# 4    0.469634  0.047580  0.601768  0.487105  0.211021
# ..        ...       ...       ...       ...       ...
# 339  0.189317  0.130833  0.329654  0.703643  0.906351
# 340  0.886640  0.362789  0.524066  0.570495  0.085230
# 341  0.875973  0.079063  0.826331  0.397589  0.061336
# 342  0.209615  0.074196  0.853506  0.931443  0.013003
# 343  0.760876  0.425754  0.781339  0.411569  0.535359
#
# [344 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  344.000000  344.000000  344.000000  344.000000  344.000000
# mean     0.500105    0.473384    0.509396    0.497997    0.500867
# std      0.278301    0.273848    0.282925    0.275769    0.289915
# min      0.002711    0.002068    0.003074    0.009614    0.001487
# 25%      0.270625    0.230248    0.272153    0.266721    0.249886
# 50%      0.497583    0.466066    0.526577    0.493991    0.522486
# 75%      0.731572    0.705044    0.735327    0.710114    0.758235
# max      0.996132    0.995441    0.992159    0.999471    0.999273

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0
# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0       647  0.646496  0.434950  0.414120  0.522965
# 1  0.932872  0.042763  0.513731  0.237541  0.836702

# %%
#as we have change columen indexing so in I want to change it 

newdf.loc[0,0]=6574
newdf.head()
# Out:
#           A         B         C         D         E       0
# 0       647  0.646496  0.434950  0.414120  0.522965  6574.0
# 1  0.932872  0.042763  0.513731  0.237541  0.836702     NaN
# 2  0.785173  0.663153  0.049380  0.763408  0.525720     NaN
# 3   0.73537  0.685781  0.842727  0.632564  0.543993     NaN
# 4  0.469634  0.047580  0.601768  0.487105  0.211021     NaN

# %%
#now your abale to see that there is new column created
#we can change it by this
newdf.loc[0,'A']=6574

# %%
newdf.head()
# Out:
#           A         B         C         D         E       0
# 0      6574  0.646496  0.434950  0.414120  0.522965  6574.0
# 1  0.932872  0.042763  0.513731  0.237541  0.836702     NaN
# 2  0.785173  0.663153  0.049380  0.763408  0.525720     NaN
# 3   0.73537  0.685781  0.842727  0.632564  0.543993     NaN
# 4  0.469634  0.047580  0.601768  0.487105  0.211021     NaN

# %%
#To remove 0th colume as you can see the above we will write the following code
newdf.drop(0,axis=1)
# Out:
#             A         B         C         D         E
# 0        6574  0.646496  0.434950  0.414120  0.522965
# 1    0.932872  0.042763  0.513731  0.237541  0.836702
# 2    0.785173  0.663153  0.049380  0.763408  0.525720
# 3     0.73537  0.685781  0.842727  0.632564  0.543993
# 4    0.469634  0.047580  0.601768  0.487105  0.211021
# ..        ...       ...       ...       ...       ...
# 339  0.189317  0.130833  0.329654  0.703643  0.906351
# 340   0.88664  0.362789  0.524066  0.570495  0.085230
# 341  0.875973  0.079063  0.826331  0.397589  0.061336
# 342  0.209615  0.074196  0.853506  0.931443  0.013003
# 343  0.760876  0.425754  0.781339  0.411569  0.535359
#
# [344 rows x 5 columns]

# %%
newdf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.513731  0.237541
# 2  0.049380  0.763408

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E   0
# 1  0.932872  0.042763  0.513731  0.237541  0.836702 NaN
# 2  0.785173  0.663153  0.049380  0.763408  0.525720 NaN

# %%
#running some queryes
newdf.loc[(newdf['A']<0.3)&(newdf['C']<0.7)]
# Out:
#             A         B         C         D         E   0
# 11   0.033392  0.053197  0.646634  0.198641  0.334934 NaN
# 12   0.200005  0.712196  0.464122  0.886346  0.437479 NaN
# 13   0.050278  0.279417  0.229627  0.819895  0.207549 NaN
# 17   0.061397  0.181722  0.555067  0.033856  0.445762 NaN
# 19   0.271956  0.507846  0.482068  0.414752  0.494714 NaN
# ..        ...       ...       ...       ...       ...  ..
# 321  0.099094  0.973307  0.627613  0.551337  0.679805 NaN
# 323  0.040446  0.281340  0.279872  0.067667  0.037708 NaN
# 324  0.294335  0.372887  0.664191  0.900074  0.456635 NaN
# 337  0.170467  0.590274  0.466374  0.163738  0.292123 NaN
# 339  0.189317  0.130833  0.329654  0.703643  0.906351 NaN
#
# [70 rows x 6 columns]

# %%
newdf.iloc[0,4]
#here we are using iloc so we can use index values to get the answer
# Out:
# 0.5229653232719227

# %%
newdf.iloc[[0,5],[1,2]]
# Out:
#           B         C
# 0  0.646496  0.434950
# 5  0.465830  0.893264

# %%
newdf.drop([0])
#this command drop 0th row
# Out:
#             A         B         C         D         E   0
# 1    0.932872  0.042763  0.513731  0.237541  0.836702 NaN
# 2    0.785173  0.663153  0.049380  0.763408  0.525720 NaN
# 3     0.73537  0.685781  0.842727  0.632564  0.543993 NaN
# 4    0.469634  0.047580  0.601768  0.487105  0.211021 NaN
# 5     0.82845  0.465830  0.893264  0.711199  0.918590 NaN
# ..        ...       ...       ...       ...       ...  ..
# 339  0.189317  0.130833  0.329654  0.703643  0.906351 NaN
# 340   0.88664  0.362789  0.524066  0.570495  0.085230 NaN
# 341  0.875973  0.079063  0.826331  0.397589  0.061336 NaN
# 342  0.209615  0.074196  0.853506  0.931443  0.013003 NaN
# 343  0.760876  0.425754  0.781339  0.411569  0.535359 NaN
#
# [343 rows x 6 columns]

# %%
# now to drop colume we use axis=1 as axis =0 is by defalte selected and 
#and 1 is use for coloumn and 0 is use for row

# %%
# to drop cololumn 
newdf.drop(['A','D'],axis=1,inplace=True)

# %%
newdf
# Out:
#             B         C         E       0
# 0    0.646496  0.434950  0.522965  6574.0
# 1    0.042763  0.513731  0.836702     NaN
# 2    0.663153  0.049380  0.525720     NaN
# 3    0.685781  0.842727  0.543993     NaN
# 4    0.047580  0.601768  0.211021     NaN
# ..        ...       ...       ...     ...
# 339  0.130833  0.329654  0.906351     NaN
# 340  0.362789  0.524066  0.085230     NaN
# 341  0.079063  0.826331  0.061336     NaN
# 342  0.074196  0.853506  0.013003     NaN
# 343  0.425754  0.781339  0.535359     NaN
#
# [344 rows x 4 columns]

# %%
newdf.drop([0],axis=1)
# Out:
#             B         C         E
# 0    0.646496  0.434950  0.522965
# 1    0.042763  0.513731  0.836702
# 2    0.663153  0.049380  0.525720
# 3    0.685781  0.842727  0.543993
# 4    0.047580  0.601768  0.211021
# ..        ...       ...       ...
# 339  0.130833  0.329654  0.906351
# 340  0.362789  0.524066  0.085230
# 341  0.079063  0.826331  0.061336
# 342  0.074196  0.853506  0.013003
# 343  0.425754  0.781339  0.535359
#
# [344 rows x 3 columns]

# %%
newdf.head(3)
# Out:
#           B         C         E       0
# 0  0.646496  0.434950  0.522965  6574.0
# 1  0.042763  0.513731  0.836702     NaN
# 2  0.663153  0.049380  0.525720     NaN

# %%
newdf['B'].isnull()
#it is returning false because no value is non
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: B, Length: 344, dtype: bool

# %%
#if you what all the vlues to none
newdf['B']=None

# %%
newdf['B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 339    True
# 340    True
# 341    True
# 342    True
# 343    True
# Name: B, Length: 344, dtype: bool

# %%
newdf
# Out:
#         B         C         E       0
# 0    None  0.434950  0.522965  6574.0
# 1    None  0.513731  0.836702     NaN
# 2    None  0.049380  0.525720     NaN
# 3    None  0.842727  0.543993     NaN
# 4    None  0.601768  0.211021     NaN
# ..    ...       ...       ...     ...
# 339  None  0.329654  0.906351     NaN
# 340  None  0.524066  0.085230     NaN
# 341  None  0.826331  0.061336     NaN
# 342  None  0.853506  0.013003     NaN
# 343  None  0.781339  0.535359     NaN
#
# [344 rows x 4 columns]

# %%
newdf.loc[:,['B']]=56

# %%
newdf
# Out:
#       B         C         E       0
# 0    56  0.434950  0.522965  6574.0
# 1    56  0.513731  0.836702     NaN
# 2    56  0.049380  0.525720     NaN
# 3    56  0.842727  0.543993     NaN
# 4    56  0.601768  0.211021     NaN
# ..   ..       ...       ...     ...
# 339  56  0.329654  0.906351     NaN
# 340  56  0.524066  0.085230     NaN
# 341  56  0.826331  0.061336     NaN
# 342  56  0.853506  0.013003     NaN
# 343  56  0.781339  0.535359     NaN
#
# [344 rows x 4 columns]

# %%
df = pd.DataFrame(
    {
        "Name": [
            np.nan,
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, np.nan, 58],
        "Sex": ["male", "male", np.nan],
    }
)

# %%
df
# Out:
#                        Name   Age   Sex
# 0                       NaN  22.0  male
# 1  Allen, Mr. William Henry   NaN  male
# 2  Bonnell, Miss. Elizabeth  58.0   NaN

# %%
df.dropna(how='all',axis=1)
# Out:
#                        Name   Age   Sex
# 0                       NaN  22.0  male
# 1  Allen, Mr. William Henry   NaN  male
# 2  Bonnell, Miss. Elizabeth  58.0   NaN

# %%
df.drop_duplicates(subset=['Name'])
# Out:
#                        Name   Age   Sex
# 0                       NaN  22.0  male
# 1  Allen, Mr. William Henry   NaN  male
# 2  Bonnell, Miss. Elizabeth  58.0   NaN

# %%
df['Name'].value_counts(dropna=False)
# Out:
# Name
# NaN                         1
# Allen, Mr. William Henry    1
# Bonnell, Miss. Elizabeth    1
# Name: count, dtype: int64

# %%
df
# Out:
#                        Name   Age   Sex
# 0                       NaN  22.0  male
# 1  Allen, Mr. William Henry   NaN  male
# 2  Bonnell, Miss. Elizabeth  58.0   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      object
#  1   Age     2 non-null      float64
#  2   Sex     2 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.isnull()
#true where the value is null and false where the value is not nan
# Out:
#     Name    Age    Sex
# 0   True  False  False
# 1  False   True  False
# 2  False  False   True

# %%
#create a dataframe which contain only integers with 3 row and 2 columns
#run following dataframe methods on then :

# %%
dataf=pd.read_csv("Salary_Data.csv")
dataf
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
dataf.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
dataf.mean()
# Out:
# YearsExperience        5.313333
# Salary             76003.000000
# dtype: float64

# %%
dataf.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
dataf.count()
# Out:
# YearsExperience    30
# Salary             30
# dtype: int64

# %%
dataf.max()
# Out:
# YearsExperience        10.5
# Salary             122391.0
# dtype: float64

# %%
dataf.median()
# Out:
# YearsExperience        4.7
# Salary             65237.0
# dtype: float64

# %%
dataf.std()
# Out:
# YearsExperience        2.837888
# Salary             27414.429785
# dtype: float64
